# %% [markdown]
# # How to query for astrophysical data analysis
#
# So far I have used
# - Astropy
# - Astroquery
# - PyVO

# %%
from astropy import table
from astropy.coordinates import SkyCoord
from pyvo import registry


my_obj = SkyCoord.from_name("Bellatrix")
for res in registry.search(waveband="infrared", servicetype="spectrum"):
    print(res.service.search(pos=my_obj, size=0.001))

# %%
from astroquery.ipac.nexsci.nasa_exoplanet_archive import NasaExoplanetArchive


def query_multi_star_systems():
    # Query the database for systems with more than one star
    query_result = NasaExoplanetArchive.query_criteria(table="ps", select="*", where="sy_snum > 1")

    # Check if there are any results
    if len(query_result) == 0:
        print("No multi-star systems found.")
        return

    # Get the column names and print them
    column_names = query_result.columns
    print("Column Headers:")
    for column_name in column_names:
        print(column_name)

if __name__ == "__main__":
    query_multi_star_systems()

# %%
from astropy import table
from pyvo import registry

QUERY = "SELECT TOP 1 s_ra, s_dec from ivoa.obscore"

results = []
for svc_rec in registry.search(
          datamodel="obscore", servicetype="tap"):
      print("Querying {}".format(svc_rec.res_title))
      try:
          svc = svc_rec.get_service("tap")
          results.append(
              svc.run_sync(QUERY).to_table())
      except KeyboardInterrupt:
          # someone lost their patience with a service.  Query next.
          pass
      except Exception as msg:
          # some service is broken; you *should* complain, but
          print("  Broken: {} ({}).  Complain to {}.\n".format(
              svc_rec.ivoid, msg, svc_rec.get_contact()))

total_result = table.vstack(results)
print(total_result)
# Out:
# Querying MAST STScI CAOM and ObsCore TAP service
# Querying UCL DaCHS server TAP service
# Querying The VO @ ASTRON TAP service
# Querying AIASCR VO Services TAP service
# Querying CSIRO Australia Telescope Online Archive TAP Service
# Querying CSIRO ASKAP Science Data Archive TAP Service
#   Broken: ivo://au.csiro/casda/tap (ConnectTimeout: HTTPSConnectionPool(host='casda.csiro.au', port=443): Max retries exceeded with url: /casda_vo_tools/tap/sync (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000025116306C10>, 'Connection to casda.csiro.au timed out. (connect timeout=None)'))).  Complain to James Dempsey <james.dempsey@csiro.au>.
#
# Querying VESPA PA team server TAP service
# Querying ArVO Byurakan TAP service
# Querying CADC Archive Query Service
# Querying J-PLUS DR1 Catalogue (July, 2018)
# Querying J-PLUS DR2 Catalogue (July, 2020)
# Querying J-PLUS DR3 Catalogue (July, 2022)
# Querying MINIJ-PAS PDR201912 Catalogue (December, 2019)
# Querying ChiVO TAP service
# Querying ESO TAP_OBS: a TAP service to browse and access raw and reduced data, and to query the ambient measurements, of the La Silla Paranal Observatory.
# Querying FAI archives TAP service
# Querying Planetary web services @ FUB TAP service
# Querying Laurino et al 2011 Catalog of WGE photometric redshifts for SDSS candidate qsos and galaxies
#   Broken: ivo://ia2.inaf.it/hosted/laurino2011/tap (IllegalArgumentException: Table [ ivoa.obscore ] is not found in TapSchema).  Complain to IA2 <ia2@oats.inaf.it>.
#
# Querying IAPS TAP SERVICES TAP service
#   Broken: ivo://ia2.inaf.it/tap (ConnectTimeout: HTTPConnectionPool(host='vo-node1.iaps.inaf.it', port=80): Max retries exceeded with url: /tap/sync (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000025116304050>, 'Connection to vo-node1.iaps.inaf.it timed out. (connect timeout=None)'))).  Complain to VOIAPS team (0039 06 45 48 8766) <stavro.ivanovski@iaps.inaf.it>.
#
# Querying IAP - DaCHS Services TAP service
#   Broken: ivo://iap/tap (404 Client Error: Not Found for url: http://dorotka.ufa.cas.cz//tap/sync).  Complain to David Pisa <dp@ufa.cas.cz>.
#
# Querying EVN Data Archive TAP service
# Querying JVO ALMA VO Service
# Querying AKARI Asteroid Flux Catalogue Version 1
# Querying AKARI/IRC NIR Low-resolution Spectral Catalogue of Diffuse Sky Patches
# Querying AKARI/IRC NIR Spectral Atlas of Galactic Planetary Nebulae
# Querying AKARI/IRC MIR-S slit-less spectroscopic catalogue
# Querying HALCA VSOP (the VLBI Space Observatory Programme) Correlated Data
# Querying The VSOP (the VLBI Space Observatory Programme) 5 GHz AGN (Active Galactic Nuclei) Survey Program Analysis Data
# Querying Hitomi Master Catalog
# Querying Nobeyama Radio Telescope FITS Archive
# Querying Subaru Suprime-Cam data service
# Querying KSB-ROB TAP service
#   Broken: ivo://ksb-orb.dc/tap (connection pool is closed).  Complain to Freek Verstringe <freek.verstringe@oma.be>.
#
# Querying CeSAM Virtual Observatory Server TAP service
# Querying MACHO TAP
#   Broken: ivo://nci.org.au/macho/tap (Unable to interpret query 'Unknown table "ivoa.obscore" ! [l.1 c.31 - l.1 c.43]
# Unknown column "s_ra" ! [l.1 c.14 - l.1 c.18]
# Unknown column "s_dec" ! [l.1 c.20 - l.1 c.25]').  Complain to NCI ASVO <asvo@nci.org.au>.
#
# Querying SkyMapper TAP
#   Broken: ivo://nci.org.au/skymapper/tap (Unable to interpret query 'Unknown table "ivoa.obscore" ! [l.1 c.31 - l.1 c.43]
# Unknown column "s_ra" ! [l.1 c.14 - l.1 c.18]
# Unknown column "s_dec" ! [l.1 c.20 - l.1 c.25]').  Complain to NCI ASVO <asvo@nci.org.au>.
#
# Querying WiggleZ Final Data Release TAP
#   Broken: ivo://nci.org.au/wigglez/tap (Unable to interpret query 'Unknown table "ivoa.obscore" ! [l.1 c.31 - l.1 c.43]
# Unknown column "s_ra" ! [l.1 c.14 - l.1 c.18]
# Unknown column "s_dec" ! [l.1 c.20 - l.1 c.25]').  Complain to NCI ASVO <asvo@nci.org.au>.
#
# Querying GAVO Data Center TAP service
# Querying PADC TAP Server on voparis-tap-astro.obspm.fr TAP service
# Querying PADC TAP Server on voparis-tap-he.obspm.fr TAP service
# Querying PADC TAP Server on voparis-rr.obspm.fr TAP service
# Querying PVOL EPN-TAP TAP service
#   Broken: ivo://pvol/tap (ConnectTimeout: HTTPConnectionPool(host='pvol2.ehu.eus', port=8083): Max retries exceeded with url: /tap/sync (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000002511622C250>, 'Connection to pvol2.ehu.eus timed out. (connect timeout=None)'))).  Complain to Ricardo Hueso (Delete this line if you don't want to give it) <ricardo.hueso@ehu.eus>.
#
# Querying Cross section values TAP service
# Querying SSDC TAP Service
#   Broken: ivo://ssdc/tap (IllegalArgumentException: Table [ ivoa.obscore ] is not found in TapSchema).  Complain to SSDC Support Team <help_desk@ssdc.asi.it>.
#
# Querying ARI's Gaia TAP Service
# Querying VOXastro Data Center TAP service
# Querying TAP interface of the 3XMM-DR5 XMM-Newton Catalogue
#   Broken: ivo://xcatdb/3xmmdr5/tap (No matching interface.).  Complain to Lauretn MICHEL ((33-0) 368 852 437) <Laurent.michel@astro.unistra.fr>.
#
# Querying TAP interface of the 3XMM-dr7 XMM-Newton Catalogue
#   Broken: ivo://xcatdb/3xmmdr7/tap (TooManyRedirects: Exceeded 30 redirects.).  Complain to Laurent Michel ((33-0) 368 852 437) <Laurent.michel@astro.unistra.fr>.
#
# Querying TAP interface of the 4XMM dr13 XMM-Newton Catalogue
#   Broken: ivo://xcatdb/4xmm/tap (Incorrect ADQL query: 3 unresolved identifiers: obscore [l.1 c.31 - l.1 c.43], s_ra [l.1 c.14 - l.1 c.18], s_dec [l.1 c.20 - l.1 c.25]!
#   - Unknown table "ivoa.obscore" !
#   - Unknown column "s_ra" !
#   - Unknown column "s_dec" !).  Complain to Laurent Michel ((33-0) 368 852 437) <Laurent.michel@astro.unistra.fr>.
# ---------------------------------------------------------------------------
# TableMergeError                           Traceback (most recent call last)
# Cell In[2], line 22
#      17       except Exception as msg:
#      18           # some service is broken; you *should* complain, but
#      19           print("  Broken: {} ({}).  Complain to {}.\n".format(
#      20               svc_rec.ivoid, msg, svc_rec.get_contact()))
# ---> 22 total_result = table.vstack(results)
#      23 print(total_result)
#
# File c:\Users\manif\anaconda3\envs\astro\Lib\site-packages\astropy\table\operations.py:682, in vstack(tables, join_type, metadata_conflicts)
#     679     return tables[0]  # no point in stacking a single table
#     680 col_name_map = OrderedDict()
# --> 682 out = _vstack(tables, join_type, col_name_map, metadata_conflicts)
#     684 # Merge table metadata
#     685 _merge_table_meta(out, tables, metadata_conflicts=metadata_conflicts)
#
# File c:\Users\manif\anaconda3\envs\astro\Lib\site-packages\astropy\table\operations.py:1481, in _vstack(arrays, join_type, col_name_map, metadata_conflicts)
#    1477     raise NotImplementedError(
#    1478         f"vstack unavailable for mixin column type(s): {col_cls.__name__}"
#    1479     )
#    1480 try:
# -> 1481     col = col_cls.info.new_like(cols, n_rows, metadata_conflicts, out_name)
#    1482 except metadata.MergeConflictError as err:
#    1483     # Beautify the error message when we are trying to merge columns with incompatible
#    1484     # types by including the name of the columns that originated the error.
#    1485     raise TableMergeError(
#    1486         "The '{}' columns have incompatible types: {}".format(
#    1487             out_name, err._incompat_types
#    1488         )
#    1489     ) from err
#
# File c:\Users\manif\anaconda3\envs\astro\Lib\site-packages\astropy\table\column.py:482, in ColumnInfo.new_like(self, cols, length, metadata_conflicts, name)
#     457 def new_like(self, cols, length, metadata_conflicts="warn", name=None):
#     458     """
#     459     Return a new Column instance which is consistent with the
#     460     input ``cols`` and has ``length`` rows.
#    (...)
#     480
#     481     """
# --> 482     attrs = self.merge_cols_attributes(
#     483         cols, metadata_conflicts, name, ("meta", "unit", "format", "description")
#     484     )
#     486     return self._parent_cls(length=length, **attrs)
#
# File c:\Users\manif\anaconda3\envs\astro\Lib\site-packages\astropy\utils\data_info.py:757, in BaseColumnInfo.merge_cols_attributes(cols, metadata_conflicts, name, attrs)
#     755 uniq_shapes = {col.shape[1:] for col in cols}
#     756 if len(uniq_shapes) != 1:
# --> 757     raise TableMergeError("columns have different shapes")
#     758 out["shape"] = uniq_shapes.pop()
#     760 # "Merged" output name is the supplied name
#
# TableMergeError: columns have different shapes
